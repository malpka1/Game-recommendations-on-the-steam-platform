# %% [markdown]
# # Model building recommender system uses TF-IDF to vectorize game tags.

# %%
pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552447 sha256=b96d64fdffbe1c643dbba1534a8b0e190180495b8a2343822b4036e616e045b1
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# imports
import gdown
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from annoy import AnnoyIndex
from sklearn.preprocessing import normalize
from IPython.display import display
from sklearn.metrics import precision_score, recall_score
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import os
import pickle
from annoy import AnnoyIndex

# %%
# downloading a file
file_id = '11SQ7kKA4MslkNrF6eq7u0sm541i1WH7d'
url = f'https://drive.google.com/uc?id={file_id}'
output = 'sampled_data.csv'

gdown.download(url, output, quiet=False)

sampled_data = pd.read_csv(output)
sampled_data.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11SQ7kKA4MslkNrF6eq7u0sm541i1WH7d
# From (redirected): https://drive.google.com/uc?id=11SQ7kKA4MslkNrF6eq7u0sm541i1WH7d&confirm=t&uuid=2b76ae8c-3f5e-4ce6-9190-414be8586d41
# To: /content/sampled_data.csv
# 100%|██████████| 247M/247M [00:02<00:00, 116MB/s]
#     app_id                                        tags_string  user_id  \
# 0   951440  Open World Survival Craft, Survival, Open Worl...  9074881
# 1    32440  LEGO, Local Co-Op, Adventure, Co-op, Family Fr...  6006822
# 2   615610  Indie, Casual, Action, Space, 2D, Singleplayer...     1239
# 3  1097840  Action, Adventure, Multiplayer, Third-Person S...  9255103
# 4   464060  Cyberpunk, Action, Top-Down Shooter, Great Sou...  5324004
#
#                                   title  rating_numeric
# 0                            Volcanoids             4.5
# 1  LEGO® Star Wars™ - The Complete Saga             5.0
# 2                               Orbt XL             5.0
# 3                               Gears 5             3.5
# 4                                RUINER             4.5

# %%
content_df = sampled_data [['user_id', 'app_id', 'title', 'tags_string']]
content_df.head()
# Out:
#    user_id   app_id                                 title  \
# 0  9074881   951440                            Volcanoids
# 1  6006822    32440  LEGO® Star Wars™ - The Complete Saga
# 2     1239   615610                               Orbt XL
# 3  9255103  1097840                               Gears 5
# 4  5324004   464060                                RUINER
#
#                                          tags_string
# 0  Open World Survival Craft, Survival, Open Worl...
# 1  LEGO, Local Co-Op, Adventure, Co-op, Family Fr...
# 2  Indie, Casual, Action, Space, 2D, Singleplayer...
# 3  Action, Adventure, Multiplayer, Third-Person S...
# 4  Cyberpunk, Action, Top-Down Shooter, Great Sou...

# %%
def preprocess_tags(tags):
    # removing special characters and converting to lower case
    tags = re.sub(r'[^\w\s]', '', tags).lower()
    return tags

# %%
content_df['tags_string'] = content_df['tags_string'].fillna('').apply(preprocess_tags)
# Out:
# <ipython-input-8-20d8dd7235d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content_df['tags_string'] = content_df['tags_string'].fillna('').apply(preprocess_tags)

# %% [markdown]
# # Tags information

# %%
# separating tags and collecting them into one list
all_tags = ' '.join(content_df['tags_string']).split()
unique_tags = set(all_tags)
tag_counts = Counter(all_tags)

# tag information output
print(f'Total unique tags: {len(unique_tags)}')
print(f'Unique tags: {unique_tags}')
print(f'Frequency of occurrence of tags: {tag_counts}')
# Out:
# Total unique tags: 483
# Unique tags: {'boxing', 'postapocalyptic', 'voxel', 'crpg', 'coding', 'minimalist', 'martial', 'film', 'tactics', 'atv', 'fighter', '1980s', 'asynchronous', 'visual', 'god', 'military', 'soccer', 'physics', 'audio', 'dark', 'space', 'protagonist', 'swordplay', 'workshop', 'isometric', 'colony', 'friendly', 'trivia', 'deckbuilding', 'sailing', 'with', 'room', 'humor', 'cooking', 'rush', 'editing', 'immersive', 'replay', 'scroller', 'motorbike', 'werewolves', 'steampunk', 'character', 'procedural', 'online', 'combat', 'roguelike', 'gridbased', 'intentionally', 'bullet', 'mars', 'inventory', 'farming', 'rome', 'hockey', 'zombies', 'controls', 'real', 'grid', 'board', 'economy', 'nature', 'animation', 'romance', 'dystopian', 'robots', 'player', 'multiple', 'survival', 'fiction', 'death', 'tower', 'simulation', 'mystery', 'turnbased', 'hobby', 'shooter', 'wargame', 'warhammer', 'fastpaced', 'villain', 'card', 'gothic', 'history', '1990s', 'bikes', 'base', 'kickstarter', 'trains', 'driving', 'satire', 'on', 'photo', 'wellwritten', 'unforgiving', 'access', 'touchfriendly', 'management', 'graphics', 'esports', 'social', 'foreign', 'play', 'short', 'pool', 'mechs', 'world', '3', 'jrpg', 'crime', 'choose', 'stealth', 'volleyball', 'bmx', 'destruction', 'soulslike', 'exploration', 'puzzle', 'mature', 'open', 'roguevania', 'solitaire', 'comic', 'customization', 'mythology', 'pinball', 'free', 'up', 'bowling', 'female', 'massively', 'party', 'capitalism', 'deckbuilder', 'hero', 'quicktime', 'programming', 'soundtrack', 'sokoban', 'tennis', 'naval', 'video', 'jet', 'benchmark', 'remake', 'creature', 'chess', 'archery', 'pirates', 'own', 'simulator', 'dinosaurs', 'shop', 'fox', 'lgbtq', 'gun', 'awkward', 'blood', 'thriller', 'beautiful', 'royale', 'fishing', 'scifi', 'pixel', 'mini', 'baseball', 'idler', 'publishing', 'to', 'cartoon', 'twin', 'vikings', 'conspiracy', 'cartoony', 'arcade', 'wholesome', 'episodic', 'traditional', 'lorerich', 'generation', 'actionadventure', 'old', 'coop', '2d', 'singleplayer', 'rich', 'musicbased', 'crawler', 'war', 'family', 'collectathon', 'minigames', 'western', 'roguelite', 'city', 'flight', 'design', 'clicker', 'outbreak', 'gambling', 'silent', 'em', 'only', 'walking', 'surreal', 'sequel', 'perma', 'violent', 'football', 'movie', 'parody', 'spaceships', 'epic', 'mahjong', 'golf', 'lovecraftian', 'vr', 'great', 'realtime', 'wrestling', 'intelligence', 'medical', 'american', 'underwater', 'development', 'hardware', 'agriculture', 'modern', 'web', 'crowdfunded', 'relaxing', 'manipulation', 'defense', 'interactive', 'narrative', 'stylized', 'sniper', 'point', 'philosophical', 'cult', 'training', 'magic', 'illuminati', 'instrumental', 'local', 'snowboarding', 'musou', 'precision', '8bit', 'cricket', 'anime', 'atmospheric', 'sexual', 'handdrawn', 'story', 'escape', 'hacking', 'cyberpunk', 'basketball', 'assassin', 'nsfw', 'fighting', 'tactical', 'vision', 'control', 'automobile', 'superhero', 'rugby', 'cinematic', 'content', 'sports', 'artificial', 'score', 'realistic', 'parkour', 'diplomacy', 'gore', 'a', 'campaign', 'arena', 'pve', 'cute', 'person', 'hell', 'trading', '40k', 'machine', 'psychedelic', 'click', 'dragons', 'novel', 'i', 'dynamic', 'vehicular', 'mining', 'offroad', 'supernatural', 'topdown', '4x', 'based', 'jump', 'games', 'america', 'rpgmaker', 'utilities', 'noir', 'collector', 'illustration', 'third', 'demons', 'mmorpg', 'lemmings', 'events', 'hack', 'drama', 'loot', 'modeling', 'controller', 'onrails', 'beat', 'sim', 'transhumanism', 'object', 'hunting', 'asymmetric', 'strategy', 'scare', 'submarine', 'crafting', 'attack', 'rock', 'hex', 'side', 'cats', 'mouse', 'match', 'nostalgia', 'underground', 'horror', 'grand', 'level', 'experience', 'boss', 'builder', 'resource', 'experimental', 'colorful', 'school', 'futuristic', 'reboot', 'tilematching', 'deduction', 'automation', 'motocross', 'indie', 'fps', 'lego', 'moba', 'snooker', 'typing', 'matter', 'dating', 'ninja', 'movement', 'nudity', 'hidd ...
# Frequency of occurrence of tags: Counter({'singleplayer': 801529, 'action': 794662, 'adventure': 644291, 'multiplayer': 614353, 'indie': 511461, 'coop': 511447, 'shooter': 457572, 'atmospheric': 436663, 'rpg': 404532, 'horror': 376146, 'soundtrack': 362409, 'story': 356865, 'rich': 356865, 'great': 351957, 'world': 345272, 'strategy': 329437, 'open': 312404, 'firstperson': 284669, '2d': 284605, 'survival': 282249, 'casual': 278408, 'simulation': 224132, 'third': 223458, 'person': 223458, 'fps': 218367, 'funny': 217932, 'puzzle': 212752, 'fantasy': 205651, 'platformer': 198379, 'difficult': 194038, 'dark': 182329, 'scifi': 178754, 'gore': 175662, 'protagonist': 173184, 'sandbox': 165211, 'comedy': 156609, 'online': 154510, 'exploration': 154345, 'free': 152894, 'to': 152894, 'play': 152894, 'female': 150442, 'turnbased': 148504, 'local': 147785, 'psychological': 137917, '3d': 135916, 'violent': 133896, 'sim': 133755, 'classic': 130537, 'anime': 130389, 'pixel': 120146, 'graphics': 120146, 'pvp': 115695, 'management': 114873, 'tactical': 111991, 'war': 111300, 'building': 107936, 'cute': 107124, 'controller': 100094, 'early': 95721, 'access': 95721, 'thirdperson': 94480, 'stealth': 92924, 'customization': 91082, 'character': 91048, 'nudity': 91009, 'combat': 86958, 'family': 86666, 'friendly': 86666, 'retro': 86195, 'roguelike': 85245, 'colorful': 83571, 'choices': 83149, 'matter': 83149, 'arcade': 82766, 'moddable': 81422, 'novel': 79422, 'hack': 78951, 'and': 78951, 'slash': 78951, 'realistic': 78825, 'sexual': 78538, 'content': 78538, 'massively': 78318, 'actionadventure': 77292, 'zombies': 76910, 'mystery': 74162, 'mature': 73098, 'physics': 72674, 'postapocalyptic': 70246, 'memes': 69234, 'topdown': 68923, 'game': 67644, 'time': 67107, 'point': 66582, 'click': 66582, 'crafting': 66160, 'visual': 65153, 'short': 64642, 'historical': 63652, 'replay': 62680, 'value': 62680, 'relaxing': 59888, 'fastpaced': 59424, 'competitive': 58595, 'multiple': 58573, 'endings': 58573, 'military': 58361, 'space': 58149, 'teambased': 57159, 'simulator': 56761, 'walking': 56191, 'em': 52995, 'up': 52995, 'side': 51462, 'scroller': 51462, 'medieval': 49064, 'parkour': 46184, 'rts': 46098, 'racing': 44627, 'roguelite': 44417, 'isometric': 44093, 'base': 43699, 'fighting': 42039, 'tactics': 41715, 'stylized': 40491, 'jrpg': 39645, 'drama': 39639, 'aliens': 39195, 'surreal': 38756, 'futuristic': 37769, 'humor': 37510, 'magic': 37269, 'dating': 37157, 'pve': 36425, 'resource': 36292, 'beat': 36268, 'procedural': 36252, 'generation': 36252, 'dystopian': 36125, 'emotional': 35664, 'cinematic': 35093, 'immersive': 34791, 'cyberpunk': 34440, 'card': 34408, 'realtime': 33826, 'bullet': 32855, 'romance': 32436, 'crime': 32431, 'vr': 32386, 'narration': 32377, 'metroidvania': 31831, 'handdrawn': 31123, 'fighter': 30921, 'beautiful': 30698, 'detective': 30420, 'old': 30410, 'school': 30410, 'remake': 29942, 'cartoony': 29580, 'dungeon': 28946, '1990s': 28859, 'minimalist': 28117, 'crawler': 26785, 'ii': 26502, 'music': 26438, 'sports': 26423, 'economy': 26113, 'interactive': 25437, 'fiction': 25437, 'addictive': 25317, 'level': 25066, 'editor': 25066, 'driving': 24732, 'linear': 24693, 'city': 24646, 'builder': 24646, '25d': 24440, 'choose': 24324, 'your': 24324, 'own': 24324, 'vision': 24148, 'destruction': 23001, 'soulslike': 22933, 'lgbtq': 22392, 'robots': 22268, 'esports': 21959, 'blood': 21666, 'quicktime': 21092, 'events': 21092, 'comic': 20775, 'book': 20775, 'steampunk': 20677, 'hell': 20101, 'automobile': 20094, 'perma': 19930, 'death': 19930, 'hentai': 19886, 'thriller': 19810, 'episodic': 19670, 'political': 19660, 'cartoon': 19341, 'loot': 19153, 'craft': 19116, 'tower': 18923, 'defense': 18923, 'assassin': 18797, 'mmorpg': 18466, '4': 18440, 'player': 18440, 'with': 18283, 'pause': 18283, 'attack': 18220, 'lovecraftian': 17767, 'alternate': 17751, 'history': 17751, 'cult': 17654, 'battle': 17556, 'royale': 17556, 'real': 17066, 'shoot': 16727, ...

# %%
# creating a string of all descriptions
tags_text = ' '.join(content_df['tags_string'])
# word cloud creation
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(tags_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # TF-IDF

# %%
# converting tags to TF-IDF vector representation
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(content_df['tags_string'])

# %%
# TF-IDF matrix normalization
tfidf_matrix = normalize(tfidf_matrix)

# %%
# vector dimension
f = tfidf_matrix.shape[1]

# %%
# Annoy index creation
index = AnnoyIndex(f, 'angular')

# %%
for i in range(tfidf_matrix.shape[0]):
    index.add_item(i, tfidf_matrix[i].toarray()[0])

# %%
# building a tree
index.build(10)
# Out:
# True

# %%
train_df, test_df = train_test_split(content_df, test_size=0.2, random_state=42)

# %%
def get_recommendations_for_user(user_id, content_df=content_df, index=index, tfidf_matrix=tfidf_matrix, top_n=10):
    # games that the user has already played
    user_games = content_df[content_df['user_id'] == user_id]
    user_game_indices = user_games.index
    user_game_vectors = [tfidf_matrix[i].toarray()[0] for i in user_game_indices]

    # collecting all recommendations for games that the user has already played
    recommended_indices = set()
    for vector in user_game_vectors:
        recommended_indices.update(index.get_nns_by_vector(vector, top_n * 2))

    # exclude games that the user has already played
    recommended_indices.difference_update(user_game_indices)

    # getting the names of recommended games
    recommended_games = content_df.iloc[list(recommended_indices)].drop_duplicates(subset='title').head(top_n)

    return recommended_games[['title', 'tags_string']]

# %%
# input user_id
user_id = int(input("Enter User ID: "))
# receiving recommendations
recommendations = get_recommendations_for_user(user_id, top_n=20)

if recommendations.empty:
    print("No recommendations found for this user.")
else:
    print("Recommended Games:")
    display(recommendations)
# Out:
# Enter User ID: 5324004
# Recommended Games:
#                                 title  \
# 49168                          RUINER
# 565264  Wonder Boy: The Dragon's Trap
# 73291                          Vampyr
#
#                                               tags_string
# 49168   cyberpunk action topdown shooter great soundtr...
# 565264  platformer adventure action indie remake cult ...
# 73291   vampire rpg choices matter story rich action o...

# %% [markdown]
# # Evaluate the model

# %%
def evaluate_model(train_df, test_df, content_df=content_df, index=index, tfidf_matrix=tfidf_matrix):
    all_precision = []
    all_recall = []

    for user_id in test_df['user_id'].unique():
        if user_id in train_df['user_id'].values:
            actual_games = set(test_df[test_df['user_id'] == user_id]['title'])
            recommended_games = get_recommendations_for_user(user_id, content_df, index, tfidf_matrix)['title'].tolist()

            true_positives = len(actual_games.intersection(recommended_games))
            precision = true_positives / len(recommended_games) if recommended_games else 0
            recall = true_positives / len(actual_games) if actual_games else 0

            all_precision.append(precision)
            all_recall.append(recall)

    average_precision = sum(all_precision) / len(all_precision)
    average_recall = sum(all_recall) / len(all_recall)

    return average_precision, average_recall

average_precision, average_recall = evaluate_model(train_df, test_df)
print(f"Average Precision: {average_precision:.2f}")
print(f"Average Recall: {average_recall:.2f}")
# Out:
# Average Precision: 0.37
# Average Recall: 0.97

# %% [markdown]
# # Save TF-IDF matrix, Vectorizer and AnnoyIndex

# %%
# Try to mount Google Drive to a different mount point
drive.mount('/mnt/drive')

# Directory to save models on Google Drive
model_dir = '/mnt/drive/MyDrive/models'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Saving TF-IDF matrix and Vectorizer
with open(os.path.join(model_dir, 'tfidf_matrix.pkl'), 'wb') as f:
    pickle.dump(tfidf_matrix, f)

with open(os.path.join(model_dir, 'tfidf_vectorizer.pkl'), 'wb') as f:
    pickle.dump(tfidf, f)

# Saving AnnoyIndex
index.save(os.path.join(model_dir, 'annoy_index.ann'))

print(f"Models saved in directory: {model_dir}")

# Loading TF-IDF matrix and Vectorizer
with open(os.path.join(model_dir, 'tfidf_matrix.pkl'), 'rb') as f:
    tfidf_matrix = pickle.load(f)

with open(os.path.join(model_dir, 'tfidf_vectorizer.pkl'), 'rb') as f:
    tfidf = pickle.load(f)

# Loading AnnoyIndex
f = tfidf_matrix.shape[1]
index = AnnoyIndex(f, 'angular')
index.load(os.path.join(model_dir, 'annoy_index.ann'))

print("Models loaded successfully")
# Out:
# Mounted at /mnt/drive
# Models saved in directory: /mnt/drive/MyDrive/models
# Models loaded successfully
